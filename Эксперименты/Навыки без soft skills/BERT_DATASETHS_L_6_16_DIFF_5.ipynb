# %%
#!pip install torchmetrics
import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as data
import math
import copy
import torch
import torch.nn as nn
import torch.nn.functional as F
import random
import pandas as pd
import numpy as np
from   sklearn.preprocessing   import LabelEncoder          # кодировка категорий
import pandas as pd
from torch.autograd import Variable
import numpy as np
import torch.functional as F
from   sklearn.preprocessing   import LabelEncoder          # кодировка категорий
from   sklearn.decomposition import PCA
from   sklearn import linear_model
import matplotlib.pyplot as plt                   # постороение графиков
import datetime
from sklearn.preprocessing import StandardScaler
from sklearn.manifold import TSNE
import torch.optim as optim
import torch
from torch.utils.data import DataLoader, TensorDataset
import torchmetrics

# %%
# Читаем файл с компетенциями
df = pd.read_excel('/content/DatasetHS_L_4_16_diff_5_COLAB.xlsx')

# %%
df['SKILLS'] = df['SKILLS'].astype(str)

# Длинна каждого посчитаем длинну
df['list_of_skill'] = df['SKILLS'].apply(lambda x: x.split(','))

# %%
df['cnt_skill'] = df['list_of_skill'].apply(lambda x: len(x))

# %%
df.head(5)
# Out:
#                                               SKILLS  \
# 0  НАВЫКИ КООРДИНАЦИИ И ОПЕРАТИВНОГО ПЛАНИРОВАНИЯ...
# 1  1C БУХГАЛТЕРИЯ,1C ЗАРПЛАТА И КАДРЫ,БАНК КЛИЕНТ...
# 2  1C БУХГАЛТЕРИЯ,АТТЕСТАТ ПРОФЕССИОНАЛЬНОГО БУХГ...
# 3  1C БУХГАЛТЕРИЯ,БУХГАЛТЕРСКИЙ УЧЕТ,БУХГАЛТЕРСКА...
# 4  1C БУХГАЛТЕРИЯ,РАБОТА С ПОСТАВЩИКАМИ,РАСЧЕТЫ С...
#
#                                        list_of_skill  cnt_skill
# 0  [НАВЫКИ КООРДИНАЦИИ И ОПЕРАТИВНОГО ПЛАНИРОВАНИ...         16
# 1  [1C БУХГАЛТЕРИЯ, 1C ЗАРПЛАТА И КАДРЫ, БАНК КЛИ...         16
# 2  [1C БУХГАЛТЕРИЯ, АТТЕСТАТ ПРОФЕССИОНАЛЬНОГО БУ...         16
# 3  [1C БУХГАЛТЕРИЯ, БУХГАЛТЕРСКИЙ УЧЕТ, БУХГАЛТЕР...         16
# 4  [1C БУХГАЛТЕРИЯ, РАБОТА С ПОСТАВЩИКАМИ, РАСЧЕТ...         16

# %%
df_skill = df[(df.cnt_skill > 5) & (df.cnt_skill < 17)]

# %%
data = df_skill

# %%
len(data)
# Out:
# 43847

# %%
# Создаем словарь
vocabulary = []
vocabulary.append('[PAD]')
vocabulary.append('[MASK]')
for i, row  in data.iterrows():
    for j in data["list_of_skill"][i]:
        if j not in vocabulary:
            vocabulary.append(j)
word2idx = {w: idx for (idx, w) in enumerate(vocabulary)}
idx2word = {idx: w for (idx, w) in enumerate(vocabulary)}
vocabulary_size = len(vocabulary)

# %%
vocabulary_size
# Out:
# 30018

# %%
from collections import Counter

# Создадим список всех слов в списке слов
all_words = [word for sublist in data.list_of_skill for word in sublist]

# Подсчитаем количество повторений каждого слова
word_counts = Counter(all_words)

# Выведем результат
print(word_counts)
# Out:
# Counter({'ПОЛЬЗОВАТЕЛЬ ПК': 6722, 'РАБОТА С БОЛЬШИМ ОБЪЕМОМ ИНФОРМАЦИИ': 4190, 'АНГЛИЙСКИЙ ЯЗЫК': 3788, 'АКТИВНЫЕ ПРОДАЖИ': 2999, '1С ПРЕДПРИЯТИЕ 8': 2929, 'ЗАКЛЮЧЕНИЕ ДОГОВОРОВ': 2623, 'УПРАВЛЕНИЕ ПРОЕКТАМИ': 2430, 'ПОИСК И ПРИВЛЕЧЕНИЕ КЛИЕНТОВ': 2226, 'MS POWERPOINT': 2056, 'AUTOCAD': 1974, 'EXCEL': 1926, 'SQL': 1792, 'ADOBE PHOTOSHOP': 1681, 'ВЫСШЕЕ ОБРАЗОВАНИЕ': 1650, 'ПОИСК ИНФОРМАЦИИ В ИНТЕРНЕТ': 1636, 'ВЕДЕНИЕ ОТЧЕТНОСТИ': 1618, 'B2B ПРОДАЖИ': 1551, 'GIT': 1518, 'РАБОТА С ОРГТЕХНИКОЙ': 1500, 'ОПЫТНЫЙ ПОЛЬЗОВАТЕЛЬ ПК': 1479, 'ДОКУМЕНТООБОРОТ': 1477, 'CRM': 1460, 'LINUX': 1457, 'УВЕРЕННЫЙ ПОЛЬЗОВАТЕЛЬ ПК': 1453, 'ОТВЕТСТВЕННОСТЬ И ПУНКТУАЛЬНОСТЬ': 1377, 'ДОКУМЕНТАЛЬНОЕ СОПРОВОЖДЕНИЕ': 1353, 'БУХГАЛТЕРСКАЯ ОТЧЕТНОСТЬ': 1315, 'MS OUTLOOK': 1261, 'MS EXCEL': 1243, '1С БУХГАЛТЕРИЯ': 1238, 'УПРАВЛЕНИЕ ПРОДАЖАМИ': 1227, 'ПЕРВИЧНАЯ БУХГАЛТЕРСКАЯ ДОКУМЕНТАЦИЯ': 1205, 'ХОЛОДНЫЕ ПРОДАЖИ': 1197, 'ПЕРВИЧНАЯ ДОКУМЕНТАЦИЯ': 1196, '1С ДОКУМЕНТООБОРОТ': 1193, 'ВЕДЕНИЕ КЛИЕНТСКОЙ БАЗЫ': 1175, 'PYTHON': 1123, '1C БУХГАЛТЕРИЯ': 1063, 'INTERNET': 1018, 'JAVASCRIPT': 1011, 'ЗНАНИЕ MS OFFICE': 1008, 'СТРОИТЕЛЬСТВО': 1007, 'РАБОТА С ПОСТАВЩИКАМИ': 989, 'КОНТРОЛЬ КАЧЕСТВА': 986, 'ПРОЕКТНАЯ ДОКУМЕНТАЦИЯ': 949, 'РАБОТА С БАЗАМИ ДАННЫХ': 946, 'POSTGRESQL': 946, 'БУХГАЛТЕРСКИЙ УЧЕТ': 929, 'ЗАКУПКА ТОВАРОВ И УСЛУГ': 912, '1C ПРЕДПРИЯТИЕ': 910, 'ВЕДЕНИЕ ДОКУМЕНТАЦИИ': 892, 'НАЛОГОВАЯ ОТЧЕТНОСТЬ': 887, 'HTML': 876, 'РАБОТА С ДОКУМЕНТАМИ': 864, 'РАСЧЕТ ЗАРАБОТНОЙ ПЛАТЫ': 845, 'SMM': 844, 'КОНСУЛЬТИРОВАНИЕ КЛИЕНТОВ ПО ТЕЛЕФОНУ': 839, 'СОСТАВЛЕНИЕ ДОГОВОРОВ': 819, 'ЗАКУПКИ': 811, 'ПРОДВИЖЕНИЕ БРЕНДА': 809, 'ПОДГОТОВКА ПРЕЗЕНТАЦИЙ': 792, 'УМЕНИЕ РАБОТАТЬ В РЕЖИМЕ МНОГОЗАДАЧНОСТИ': 787, 'МОТИВАЦИЯ ПЕРСОНАЛА': 782, 'ИНТЕРНЕТ РЕКЛАМА': 778, 'АНАЛИЗ РЫНКА': 768, 'C': 753, 'JAVA': 734, 'НАВЫКИ РАБОТЫ С ВОЗРАЖЕНИЯМИ': 730, 'АНАЛИТИКА ПРОДАЖ': 726, 'КАССОВЫЕ ОПЕРАЦИИ': 724, '1С ТОРГОВЛЯ': 715, 'РАБОТА В РЕЖИМЕ МНОГОЗАДАЧНОСТИ': 710, 'ПЕРВИЧНЫЕ ДОКУМЕНТЫ': 706, 'DOCKER': 703, 'КАДРОВОЕ ДЕЛОПРОИЗВОДСТВО': 701, 'ЭЛЕКТРОННЫЙ ДОКУМЕНТООБОРОТ': 688, 'ОБЕСПЕЧЕНИЕ ЖИЗНЕДЕЯТЕЛЬНОСТИ ОФИСА': 686, 'ЗНАНИЕ 1С': 682, '1С ЗАРПЛАТА И УПРАВЛЕНИЕ ПЕРСОНАЛОМ': 678, 'БАНК КЛИЕНТ': 672, 'ФИНАНСОВАЯ ОТЧЕТНОСТЬ': 671, 'СИСТЕМНОЕ МЫШЛЕНИЕ': 670, 'КОПИРАЙТИНГ': 669, 'ТЕХНИЧЕСКОЕ ОБСЛУЖИВАНИЕ': 661, 'АНАЛИЗ ДАННЫХ': 656, 'ПРОВЕДЕНИЕ ИНВЕНТАРИЗАЦИЙ': 654, 'MYSQL': 654, 'УПРАВЛЕНЧЕСКАЯ ОТЧЕТНОСТЬ': 653, 'CSS': 650, 'МАРКЕТИНГОВЫЙ АНАЛИЗ': 645, 'ИНВЕНТАРИЗАЦИЯ': 643, '1С УПРАВЛЕНИЕ ТОРГОВЛЕЙ': 642, 'БЮДЖЕТИРОВАНИЕ': 642, 'B2C ПРОДАЖИ': 641, 'ATLASSIAN JIRA': 627, 'СОПРОВОЖДЕНИЕ КЛИЕНТОВ': 620, 'ЭЛЕКТРОННАЯ ПОЧТА': 620, 'ДЕЛОВАЯ ЭТИКА': 619, 'ПЛАНИРОВАНИЕ КАРЬЕРЫ': 617, 'НАПИСАНИЕ ТЕКСТОВ': 617, 'ПОДГОТОВКА КОММЕРЧЕСКИХ ПРЕДЛОЖЕНИЙ': 611, 'MS SQL': 607, '1С БИТРИКС': 602, 'ПРОДАЖИ': 601, 'MS OFFICE': 599, 'INTERNET MARKETING': 599, 'УМЕНИЕ ПРИНИМАТЬ РЕШЕНИЯ': 597, 'РАЗРАБОТКА ПРОЕКТНОЙ ДОКУМЕНТАЦИИ': 595, 'ОЦЕНКА ПОТРЕБНОСТЕЙ КЛИЕНТОВ': 594, 'ИНЖЕНЕРНЫЕ СИСТЕМЫ': 593, 'АДМИНИСТРИРОВАНИЕ': 589, 'ЗНАНИЕ КОМПЬЮТЕРА': 589, 'ВХОДЯЩИЕ ЗВОНКИ': 584, 'РАЗРАБОТКА ТЕХНИЧЕСКИХ ЗАДАНИЙ': 572, 'ОФИСНАЯ ТЕХНИКА': 568, 'ОФОРМЛЕНИЕ ЗАКАЗОВ': 561, 'ОРГАНИЗАЦИЯ ВСТРЕЧ': 561, 'PHP': 559, 'ТЕХНИЧЕСКАЯ ДОКУМЕНТАЦИЯ': 557, 'ДОГОВОРНАЯ РАБОТА': 556, 'СПОСОБНОСТЬ БЫСТРО ОБУЧАТЬСЯ': 554, 'ВЕДЕНИЕ ПЕРЕПИСКИ': 551, 'ХОЛОДНЫЕ ЗВОНКИ': 548, 'СОГЛАСОВАНИЕ ДОГОВОРОВ': 544, 'РАБОТА С ТМЦ': 544, 'ФИНАНСОВЫЙ АНАЛИЗ': 542, 'СТРАТЕГИЧЕСКОЕ МЫШЛЕНИЕ': 542, 'МАРКЕТИНГОВЫЕ ИССЛЕДОВАНИЯ': 541, 'ООП': 525, 'КОНСУЛЬТАТИВНЫЕ ПРОДАЖИ': 515, 'РАБОТА С ЮРИДИЧЕСКИМИ ЛИЦАМИ': 514, 'ВЕДЕНИЕ ГРУПП В СОЦИАЛЬНЫХ СЕТЯХ': 512, 'РАБОТА С ТЕКУЩЕЙ БАЗОЙ КЛИЕНТОВ': 507, 'ОПЫТ ПРОДАЖ': 506, 'УЧЕТ ОСТАТКОВ': 504, 'НАПОЛНЕНИЕ КОНТЕНТОМ': 499, 'БИЗНЕС АНАЛИЗ': 498, 'НАВЫКИ РАБОТЫ С ПЕРВИЧНОЙ ДОКУМЕНТАЦИЕЙ': 494, 'ЖЕЛАНИЕ УЧИТЬСЯ И РАЗВИВАТЬСЯ': 491, 'ЖЕЛАНИЕ ОБУЧАТЬСЯ': 490, 'СКЛАДСКОЙ УЧЕТ': 490, 'КОНТЕКСТНАЯ РЕКЛАМА': 488, 'РОЗНИЧНАЯ ТОРГОВЛЯ': 487, 'СОЦИАЛЬНЫЕ СЕТИ': 487, 'АДМИНИСТРАТИВНАЯ ПОДДЕРЖКА РУКОВОДИТЕЛЯ': 486, 'GOOGLE ANALYTICS': 484, 'CORE ...

# %%
from collections import Counter

# Создадим список всех слов в списке слов
all_words = [word for sublist in data.list_of_skill for word in sublist]

# Подсчитаем количество повторений каждого слова
word_counts = Counter(all_words)

# Получим список слов, которые встречаются всего один раз
unique_words = [word for word, count in word_counts.items() if count == 1]

# Выведем результат
print(unique_words)
# Out:
# ['НАВЫКИ КООРДИНАЦИИ И ОПЕРАТИВНОГО ПЛАНИРОВАНИЯ ДЕЯТЕЛЬНОСТИ', 'УМЕНИЕ ВЗАИМОДЕЙСТВОВАТЬ С ВЫСШИМ РУКОВОДСТВОМ', 'УМЕНИЕ ПРИНИМАТЬ РЕШЕНИЯ И ДОВОДИТЬ ИХ ДО ИСПОЛНЕНИЯ', 'ЗНАНИЯ КОНСТРУКЦИИ И УСТРОЙСТВА ЛОКОМОТИВОВ СЕРИИ ТЭМ18ДМ', 'ТЭМ7А', 'ЭП2К', 'ЧС 2', 'УМЕНИЕ ПОЛЬЗОВАТЬСЯ ПРОГРАММАМИ КАСАНТ', 'КАСАТ', 'АСУТ Т', 'АС РБ', 'XL 1С', 'НАВЫКИ РАБОТЫ С INTERNET И ЭЛЕКТРОННОЙ ПОЧТОЙ', 'ПРОДВИЖЕНИЕ БРЕНДА КОМПАНИИ', 'ДОРАБОТКА САЙТА КОМПАНИИ', 'РАБОТА С АНАЛИТИКОЙ', 'РИВЛЕЧЕНИЕ ЦЕЛЕВОЙ АУДИТОРИИ', 'УПРАВЛЕНИЕ РЕПУТАЦИЕЙ БРЕНДА', 'РАЗРАБОТКА МЕТОДОЛОГИИ БИЗНЕС ПРОЦЕССОВ', 'TELEGRAMM', '1С КОРП', '1С УТ10', '1С УТ11', 'KA 1C', '1C БП', 'ПРОГРАММЫ МICROSOFT', 'УДОСТОВЕРЕНИЕ С ПРАВОМ ИСПЫТАНИЯ ОБОРУДОВАНИЯ ПОВЫШЕННЫМ НАПРЯЖЕНИЕМ', 'ЭКСПЛУАТАЦИОННЫЕ ИСПЫТАНИЯ', '500 КВ', 'ЭЛЕКТРОУСТАНОВКИ 6 500 КВ', 'ЭЛЕКТРОСЕТИ', 'ПРОВЕДЕНИЕ ИСПЫТАНИЙ И ИЗМЕРЕНИЙ', 'МОСЭНЕРГО', 'МОСИНЖПРОЕКТ', '220КВ', '110КВ', 'IP АТС', 'REMOTE DESKTOP SERVICE', 'ОРГАНИЗАЦИЯ ВИДЕО КОНФЕРЕНЦСВЯЗИ', 'PIX4D MAPPER', 'CREDO 3D СКАН', 'ОБРАБОТКА МАТЕРИАЛОВ', 'КОММУТАЦИЯ ОБОРУДОВАНИЯ', 'ЧТЕНИЕ ТЕХНИЧЕСКОЙ ЛИТЕРАТУРЫ', 'VIRTUAL STUDIO', 'AUGMENTED REALITY', 'VIRTUAL SETS', 'MODO', 'MOBILE APPS DEVELOPMENT', 'SELFSTARTER', 'ПРОГРАММИРОВАНИЕ МОБИЛЬНЫХ ПРИЛОЖЕНИЙ', 'TESTING HARDWARE COMPONENTS', 'TSEARCH', 'EXCEL ПРОДВИНУТЫЙ ПОЛЬЗОВАТЕЛЬ', 'СТАДИЯ Р', 'ГАЛЬВАНИЧЕСКИЕ ЛИНИИ', 'РАЗРАБОТКА ОСНОВНЫХ РАЗДЕЛОВ ТХ', 'ТМ', 'ТС ТЭЦ', 'КОТЕЛЬНЫХ', 'ТЕПЛОВЫХ СЕТЕЙ', 'ТЕПЛОВЫХ', 'РАЗРАБОТКА И РАСЧЕТ ТЕПЛОВОЙ СХЕМЫ', 'РАЗРАБОТКА В ПАКЕТЕ ТРЁХМЕРНОГО МОДЕЛИРОВАНИЯ ТРАССИРОВКИ ТРУБОПРОВОДОВ 10', 'УГОЛЬ', 'РУДА', 'УСТОЙЧИВОСТЬ', 'ГЕОМЕХАНИКА', 'УПРАВЛЕНИЕ СОСТОЯНИЕМ МАССИВА', 'ПЛАНИРОВАНИЕ И ОРГАНИЗАЦИИ', 'РАСЧЕТ КОНСТРУКЦИИ', 'ПРОЕКТИРОВАНИЕ АВТОМОБИЛЬНЫХ ДОРОГ', 'ПОПЕРЕЧНЫЕ ПРОДОЛЬНЫЕ ПРОФИЛИ', 'РАСЧЕТ КОНСТРУКЦИИ ДОРОЖНОЙ ОДЕЖДЫ', 'ВЕРТИКАЛЬНАЯ ГОРИЗОНТАЛЬНАЯ ПЛАНИРОВКА', 'СИСТЕМНОЕ ИНТЕГРИРОВАНИЕ', 'СИСТЕМА ЗВУКОУСИЛЕНИЯ', 'АВ', 'ТЕАТРАЛЬНАЯ ТЕХНОЛОГИЯ', 'РАЗВЛЕКАТЕЛЬНЫЙ КОНТЕНТ', 'ГЕНПОДРЯДНАЯ КОМПАНИЯ', 'КАНАЛИЗАЦИОННЫЕ ОЧИСТНЫЕ СООРУЖЕНИЯ', 'ПОДПИСАНИЕ ДОКУМЕНТАЦИИ', 'ПРОДАЖА РАСХОДНЫХ МАТЕРИАЛОВ ДЛЯ ПЕЧАТИ', 'ПРОДАЖА КАРТРИДЖЕЙ', 'ЗВОНКИ ПО ТЕЛЕФОНУ', 'МАСШТАБИРОВАНИЕ ПРОДАЖ', 'ВНЕДРЕНИЕ СТАНДАРТОВ ПРОДАЖ', 'ПРОДАЖИ НА МЕРОПРИЯТИЯХ', 'DAHUA', 'UNIVIEW', 'ПРОДАЖА УСЛУГ СТРАХОВАНИЯ', 'ПРОДАЖА ФИНАНСОВЫХ ПРОДУКТОВ', 'РАЗВИТИЕ ПАРТНЕРОВ', 'NFTABLES', 'РОБОТ', 'AGV', 'КАЛМАН', 'ПИД', 'UAV', 'DRONE', 'КОПТЕР', 'КВАДРОКОПТЕР', 'СЕРТИФИКАЦИОННЫЕ ИСПЫТАНИЯ', 'КОНТРОЛЬ ОТСУТСТВИЯ НЕДЕКЛАРИРОВАННЫХ ВОЗМОЖНОСТЕЙ', 'АНАЛИЗ ПО', 'ЕTHERNET', 'LATTICE', 'MS HYPERV', 'MCITP', '3D МОДЕЛИРОВАНИЯ', 'ПРОЕКТИРОВАНИЯ ПЕЧАТНЫХ ПЛАТ', 'ПРОЕКТИРОВАНИЕ МЕХАНОСБОРОЧНЫХ ЕДИНИЦ В САПР', 'CREATIO BPM', 'ZAHMAN', 'CONTROLLER', 'DMA', 'GAP АНАЛИЗ', 'АРХИТЕКТУРА ИНФОРМАЦИОННОЙ СИСТЕМЫ', 'SLIM', 'CRUD', 'АНАЛИТИКА РЕКЛАМНЫХ КАМПАНИЙ', 'МОБИЛЬНАЯ ВЕРСТКА', 'ВЕРСТКА ДЛЯ SEO', 'МИКРОРАЗМЕТКА', 'HP BLADESYSTEM', 'OPP', 'UI TESTING', 'DOCKER OPENSHIFT ИЛИ KUBERNETES ', 'ANGULAR CLI', 'RPC', '1С УНИВЕРСИТЕТПРОФ', 'DBEVEAR', 'SENIOR BACKEND DEVELOPER', 'VUE JS 3 0', 'SENIOR PHP DEVELOPER', 'PHP ПРОГРАММИСТ', 'XHR', 'HL БЛОК', 'MOCKK', 'POWERDNS', 'PHY', 'HP DATA PROTECTOR', 'VERITAS NET BACKUP', 'СЕРВИСЫ AMAZON', 'ЗНАНИЕ И ОПЫТ ПРИМЕНЕНИЯ МЕТОДОВ НЕРАЗРУШАЮЩЕГО КОНТРОЛЯ', 'ЗНАНИЯ И ОПЫТ ПРИМЕНЕНИЯ МЕТОДОВ ВИБРОДИАГНОСТИКИ', 'ЗНАНИЯ И ОПЫТ СТАТИСТИЧЕСКОЙ ОБРАБОТКИ ДАННЫХ', 'ЗНАНИЯ В ОБЛАСТИ ИЗМЕРЕНИЙ И ЦИФРОВОЙ ОБРАБОТКИ СИГНАЛОВ', 'ЗНАНИЯ ПО ПЛАНИРОВАНИЮ И ВЕДЕНИЮ ЭКСПЕРИМЕНТА', 'ВЛАДЕНИЕ МАТЕМАТИЧЕСКИМИ ПАКЕТАМИ RSTUDIO', 'ОПЫТ ПРОГРАММИРОВАНИЯ R', 'ПОНИМАНИЕ ПРИНЦИПОВ ОПП', 'ALDEC', 'ПРИЛОЖЕНИЯ', 'CRM ПЛАНФИКС', 'CRM BITRIX', 'ПРОСЧЕТ СТОИМОСТИ ЗАКАЗА', 'ЗАКУП ТМЦ', 'ПОЛНОЕ ВЕДЕНИЕ ДОКУМЕНТАОБОРОТА', 'DELL OPENMANAGE', 'HPIRS', 'ESIGHT', 'MS POWER QUERY', 'IPSOS COMCON', 'GFK STARTRACK', 'EUROMONITOR', 'HR МЕТРИКИ', 'HR ИНСТРУМЕНТЫ', 'MS SQL АДМИНИСТРИРОВАНИЕ', '1C АДМИНИСТРИРОВАНИЕ', 'DAG', 'MS SQL SERVER 2012 2016', 'EXCHANGE 2013 И ВЫШЕ', 'СЕРВИСЫ MS OFFICE365', 'ДБО ЮЛ', 'ПОНИМАНИЕ ГИБКИХ МЕТОДОЛОГИЙ', 'ЦИФРОВЫХ ТЕХНОЛОГ ...

# %%
len(unique_words)
# Out:
# 20391

# %%
## Преобразуйте объект Counter в DataFrame
#word_count_df = pd.DataFrame(list(word_counts.items()), columns=['Skill', 'Count'])

# %%
#word_count_df.to_excel('word_count_df.xlsx')

# %%
# Случайная сортировка списков
for index, row in data.iterrows():
    random.shuffle(row['list_of_skill'])

# %%
len_tokens = 16

# %%
data['list_of_skill'] = data['list_of_skill'].apply(lambda x: x + ['[PAD]' for _ in range(len_tokens - len(x))])
# Out:
# <ipython-input-108-653f8f11be4d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['list_of_skill'] = data['list_of_skill'].apply(lambda x: x + ['[PAD]' for _ in range(len_tokens - len(x))])

# %%
data['target']= data['list_of_skill'].apply(lambda x: x[0])
# Out:
# <ipython-input-109-213780b1f4fe>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['target']= data['list_of_skill'].apply(lambda x: x[0])

# %%
data['seq'] = data['list_of_skill'].apply(lambda x: ['[MASK]'] + x[1:] if len(x) > 0 else [])
# Out:
# <ipython-input-110-725515475f96>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['seq'] = data['list_of_skill'].apply(lambda x: ['[MASK]'] + x[1:] if len(x) > 0 else [])

# %%
data
# Out:
#                                                   SKILLS  \
# 0      НАВЫКИ КООРДИНАЦИИ И ОПЕРАТИВНОГО ПЛАНИРОВАНИЯ...
# 1      1C БУХГАЛТЕРИЯ,1C ЗАРПЛАТА И КАДРЫ,БАНК КЛИЕНТ...
# 2      1C БУХГАЛТЕРИЯ,АТТЕСТАТ ПРОФЕССИОНАЛЬНОГО БУХГ...
# 3      1C БУХГАЛТЕРИЯ,БУХГАЛТЕРСКИЙ УЧЕТ,БУХГАЛТЕРСКА...
# 4      1C БУХГАЛТЕРИЯ,РАБОТА С ПОСТАВЩИКАМИ,РАСЧЕТЫ С...
# ...                                                  ...
# 43842  ЭНЕРГЕТИКА,B2B ПРОДАЖИ,ПОИСК И ПРИВЛЕЧЕНИЕ КЛИ...
# 43843  ЭНЕРГЕТИКА,ТЕХНИЧЕСКОЕ ОБСЛУЖИВАНИЕ,ИНЖЕНЕРНЫЕ...
# 43844  ЭНЕРГИЧНОСТЬ,АКТИВНОСТЬ,СТРЕМЛЕНИЕ К ЧИСТОТЕ,У...
# 43845  ЮРИДИЧЕСКАЯ ПОДДЕРЖКА,КОНТРОЛЬ ХОЗЯЙСТВЕННОЙ Д...
# 43846  ЮРИСТ,ПО ГРАЖДАНСКИМ ДЕЛАМ,СУДЕБНЫЙ ЮРИСТ,ЮРИС...
#
#                                            list_of_skill  cnt_skill  \
# 0      [УМЕНИЕ АНАЛИЗИРОВАТЬ, ЭП2К, УМЕНИЕ ПОЛЬЗОВАТЬ...         16
# 1      [БАНК КЛИЕНТ, 1C ЗАРПЛАТА И КАДРЫ, 1С ПРЕДПРИЯ...         16
# 2      [РАСЧЕТ ЗАТРАТ, 1C БУХГАЛТЕРИЯ, РАСЧЕТ ЗАРАБОТ...         16
# 3      [КАДРОВОЕ ДЕЛОПРОИЗВОДСТВО, ПЕРВИЧНАЯ БУХГАЛТЕ...         16
# 4      [ОТЧЕТНОСТЬ В ФСС, ГОДОВОЙ БАЛАНС, БУХГАЛТЕРСК...         16
# ...                                                  ...        ...
# 43842  [ЭНЕРГЕТИКА, B2B ПРОДАЖИ, ПОИСК И ПРИВЛЕЧЕНИЕ ...          6
# 43843  [ЭНЕРГЕТИКА, ТЕХНИЧЕСКОЕ ОБСЛУЖИВАНИЕ, СТРОИТЕ...          6
# 43844  [СТРЕМЛЕНИЕ К ЧИСТОТЕ, УМЕНИЕ УПРАВЛЯТЬ ВРЕМЕН...          6
# 43845  [УМЕНИЕ РАБОТАТЬ С ПРАВОВЫМИ БАЗАМИ, ЮРИДИЧЕСК...          6
# 43846  [СУДЕБНЫЙ ЮРИСТ, ПОМОЩНИК ЮРИСТА, ПО ГРАЖДАНСК...          6
#
#                                    target  \
# 0                    УМЕНИЕ АНАЛИЗИРОВАТЬ
# 1                             БАНК КЛИЕНТ
# 2                           РАСЧЕТ ЗАТРАТ
# 3               КАДРОВОЕ ДЕЛОПРОИЗВОДСТВО
# 4                        ОТЧЕТНОСТЬ В ФСС
# ...                                   ...
# 43842                          ЭНЕРГЕТИКА
# 43843                          ЭНЕРГЕТИКА
# 43844                СТРЕМЛЕНИЕ К ЧИСТОТЕ
# 43845  УМЕНИЕ РАБОТАТЬ С ПРАВОВЫМИ БАЗАМИ
# 43846                      СУДЕБНЫЙ ЮРИСТ
#
#                                                      seq
# 0      [[MASK], ЭП2К, УМЕНИЕ ПОЛЬЗОВАТЬСЯ ПРОГРАММАМИ...
# 1      [[MASK], 1C ЗАРПЛАТА И КАДРЫ, 1С ПРЕДПРИЯТИЕ 8...
# 2      [[MASK], 1C БУХГАЛТЕРИЯ, РАСЧЕТ ЗАРАБОТНОЙ ПЛА...
# 3      [[MASK], ПЕРВИЧНАЯ БУХГАЛТЕРСКАЯ ДОКУМЕНТАЦИЯ,...
# 4      [[MASK], ГОДОВОЙ БАЛАНС, БУХГАЛТЕРСКИЙ УЧЕТ, О...
# ...                                                  ...
# 43842  [[MASK], B2B ПРОДАЖИ, ПОИСК И ПРИВЛЕЧЕНИЕ КЛИЕ...
# 43843  [[MASK], ТЕХНИЧЕСКОЕ ОБСЛУЖИВАНИЕ, СТРОИТЕЛЬСТ...
# 43844  [[MASK], УМЕНИЕ УПРАВЛЯТЬ ВРЕМЕНЕМ, ЭНЕРГИЧНОС...
# 43845  [[MASK], ЮРИДИЧЕСКАЯ ГРАМОТНОСТЬ, ЮРИДИЧЕСКАЯ ...
# 43846  [[MASK], ПОМОЩНИК ЮРИСТА, ПО ГРАЖДАНСКИМ ДЕЛАМ...
#
# [43847 rows x 5 columns]

# %%
#Сортировка полей skills_id в датасете
#data['skills_id_sort'] = data['skills_id'].apply(sorted)

# %%
#data.to_excel('data_sort.xlsx')

# %%
def tokenize_dataset(data):
    # Создание нового столбца со всеми токенизированными элементами
    data['target_id'] = data['target'].apply(lambda x:  word2idx[x])
    data['skills_id'] = data['seq'].apply(lambda x: [word2idx[word] for word in x])
    return data

# %%
data = tokenize_dataset(data)
# Out:
# <ipython-input-114-89c3f1065e40>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['target_id'] = data['target'].apply(lambda x:  word2idx[x])
# <ipython-input-114-89c3f1065e40>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['skills_id'] = data['seq'].apply(lambda x: [word2idx[word] for word in x])

# %%
#data.to_excel('data.xlsx')

# %%
data
# Out:
#                                                   SKILLS  \
# 0      НАВЫКИ КООРДИНАЦИИ И ОПЕРАТИВНОГО ПЛАНИРОВАНИЯ...
# 1      1C БУХГАЛТЕРИЯ,1C ЗАРПЛАТА И КАДРЫ,БАНК КЛИЕНТ...
# 2      1C БУХГАЛТЕРИЯ,АТТЕСТАТ ПРОФЕССИОНАЛЬНОГО БУХГ...
# 3      1C БУХГАЛТЕРИЯ,БУХГАЛТЕРСКИЙ УЧЕТ,БУХГАЛТЕРСКА...
# 4      1C БУХГАЛТЕРИЯ,РАБОТА С ПОСТАВЩИКАМИ,РАСЧЕТЫ С...
# ...                                                  ...
# 43842  ЭНЕРГЕТИКА,B2B ПРОДАЖИ,ПОИСК И ПРИВЛЕЧЕНИЕ КЛИ...
# 43843  ЭНЕРГЕТИКА,ТЕХНИЧЕСКОЕ ОБСЛУЖИВАНИЕ,ИНЖЕНЕРНЫЕ...
# 43844  ЭНЕРГИЧНОСТЬ,АКТИВНОСТЬ,СТРЕМЛЕНИЕ К ЧИСТОТЕ,У...
# 43845  ЮРИДИЧЕСКАЯ ПОДДЕРЖКА,КОНТРОЛЬ ХОЗЯЙСТВЕННОЙ Д...
# 43846  ЮРИСТ,ПО ГРАЖДАНСКИМ ДЕЛАМ,СУДЕБНЫЙ ЮРИСТ,ЮРИС...
#
#                                            list_of_skill  cnt_skill  \
# 0      [УМЕНИЕ АНАЛИЗИРОВАТЬ, ЭП2К, УМЕНИЕ ПОЛЬЗОВАТЬ...         16
# 1      [БАНК КЛИЕНТ, 1C ЗАРПЛАТА И КАДРЫ, 1С ПРЕДПРИЯ...         16
# 2      [РАСЧЕТ ЗАТРАТ, 1C БУХГАЛТЕРИЯ, РАСЧЕТ ЗАРАБОТ...         16
# 3      [КАДРОВОЕ ДЕЛОПРОИЗВОДСТВО, ПЕРВИЧНАЯ БУХГАЛТЕ...         16
# 4      [ОТЧЕТНОСТЬ В ФСС, ГОДОВОЙ БАЛАНС, БУХГАЛТЕРСК...         16
# ...                                                  ...        ...
# 43842  [ЭНЕРГЕТИКА, B2B ПРОДАЖИ, ПОИСК И ПРИВЛЕЧЕНИЕ ...          6
# 43843  [ЭНЕРГЕТИКА, ТЕХНИЧЕСКОЕ ОБСЛУЖИВАНИЕ, СТРОИТЕ...          6
# 43844  [СТРЕМЛЕНИЕ К ЧИСТОТЕ, УМЕНИЕ УПРАВЛЯТЬ ВРЕМЕН...          6
# 43845  [УМЕНИЕ РАБОТАТЬ С ПРАВОВЫМИ БАЗАМИ, ЮРИДИЧЕСК...          6
# 43846  [СУДЕБНЫЙ ЮРИСТ, ПОМОЩНИК ЮРИСТА, ПО ГРАЖДАНСК...          6
#
#                                    target  \
# 0                    УМЕНИЕ АНАЛИЗИРОВАТЬ
# 1                             БАНК КЛИЕНТ
# 2                           РАСЧЕТ ЗАТРАТ
# 3               КАДРОВОЕ ДЕЛОПРОИЗВОДСТВО
# 4                        ОТЧЕТНОСТЬ В ФСС
# ...                                   ...
# 43842                          ЭНЕРГЕТИКА
# 43843                          ЭНЕРГЕТИКА
# 43844                СТРЕМЛЕНИЕ К ЧИСТОТЕ
# 43845  УМЕНИЕ РАБОТАТЬ С ПРАВОВЫМИ БАЗАМИ
# 43846                      СУДЕБНЫЙ ЮРИСТ
#
#                                                      seq  target_id  \
# 0      [[MASK], ЭП2К, УМЕНИЕ ПОЛЬЗОВАТЬСЯ ПРОГРАММАМИ...         14
# 1      [[MASK], 1C ЗАРПЛАТА И КАДРЫ, 1С ПРЕДПРИЯТИЕ 8...         20
# 2      [[MASK], 1C БУХГАЛТЕРИЯ, РАСЧЕТ ЗАРАБОТНОЙ ПЛА...         38
# 3      [[MASK], ПЕРВИЧНАЯ БУХГАЛТЕРСКАЯ ДОКУМЕНТАЦИЯ,...         25
# 4      [[MASK], ГОДОВОЙ БАЛАНС, БУХГАЛТЕРСКИЙ УЧЕТ, О...         37
# ...                                                  ...        ...
# 43842  [[MASK], B2B ПРОДАЖИ, ПОИСК И ПРИВЛЕЧЕНИЕ КЛИЕ...        767
# 43843  [[MASK], ТЕХНИЧЕСКОЕ ОБСЛУЖИВАНИЕ, СТРОИТЕЛЬСТ...        767
# 43844  [[MASK], УМЕНИЕ УПРАВЛЯТЬ ВРЕМЕНЕМ, ЭНЕРГИЧНОС...      30014
# 43845  [[MASK], ЮРИДИЧЕСКАЯ ГРАМОТНОСТЬ, ЮРИДИЧЕСКАЯ ...       2842
# 43846  [[MASK], ПОМОЩНИК ЮРИСТА, ПО ГРАЖДАНСКИМ ДЕЛАМ...      30016
#
#                                                skills_id
# 0      [1, 7, 9, 12, 3, 17, 8, 10, 13, 4, 15, 5, 2, 1...
# 1      [1, 19, 24, 18, 22, 32, 27, 30, 23, 29, 28, 33...
# 2      [1, 18, 29, 28, 41, 35, 19, 20, 33, 39, 36, 34...
# 3      [1, 22, 42, 44, 23, 26, 20, 18, 29, 31, 47, 48...
# 4      [1, 36, 42, 31, 50, 49, 20, 26, 28, 51, 29, 38...
# ...                                                  ...
# 43842  [1, 498, 506, 5810, 4258, 25714, 0, 0, 0, 0, 0...
# 43843  [1, 1407, 682, 339, 766, 5322, 0, 0, 0, 0, 0, ...
# 43844  [1, 938, 5055, 2094, 2532, 1634, 0, 0, 0, 0, 0...
# 43845  [1, 5170, 2916, 2841, 3945, 23621, 0, 0, 0, 0,...
# 43846  [1, 19516, 30015, 3574, 30017, 3574, 0, 0, 0, ...
#
# [43847 rows x 7 columns]

# %%
data.reset_index(drop=True, inplace=True)

# %%
#data.drop_duplicates(subset='skills_id_sort', inplace=True)

# %%
# Assuming data is your pandas DataFrame
dataset = TensorDataset(torch.tensor(data['skills_id']), torch.tensor(data['target_id']))

# %%
from torch.utils.data import TensorDataset, random_split


# 95% - train, на 5% Валидируемся.
train_size = int(0.95 * len(dataset))
val_size = len(dataset) - train_size

# Разобьем на training и validation случайным образом.
train_dataset, val_dataset = random_split(dataset, [train_size, val_size])

print('{:>5,} training samples'.format(train_size))
print('{:>5,} validation samples'.format(val_size))
# Out:
# 41,654 training samples
# 2,193 validation samples

# %%
from torch.utils.data import DataLoader, RandomSampler, SequentialSampler

# Зададим размер батча для DataLoaders
batch_size = 512

# Создадим DataLoaders для training and validation.
# Примеры для train берем случайным образом.
train_dataloader = DataLoader(
            train_dataset,  # Обучающие примеры.
            sampler = RandomSampler(train_dataset), # Выбор батча случайно.
            batch_size = batch_size # Обучаем с заданным размером батча.
        )

# Для проверки порядок значения не имеет поэтому можно прочитать последовательно.
validation_dataloader = DataLoader(
            val_dataset, # Валидационные примеры.
            sampler = SequentialSampler(val_dataset), # Подаем батчи последовательно.
            batch_size = batch_size # Валидируем с заданным размером батча.
        )

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
class MultiHeadAttention(nn.Module):
    def __init__(self, d_model, num_heads):
        super(MultiHeadAttention, self).__init__()
        assert d_model % num_heads == 0, "d_model must be divisible by num_heads"

        self.d_model = d_model
        self.num_heads = num_heads
        self.d_k = d_model // num_heads

        self.W_q = nn.Linear(d_model, d_model, bias=False)
        self.W_k = nn.Linear(d_model, d_model, bias=False)
        self.W_v = nn.Linear(d_model, d_model, bias=False)
        self.W_o = nn.Linear(d_model, d_model, bias=False)

    def scaled_dot_product_attention(self, Q, K, V, mask ):
        attn_scores = torch.matmul(Q, K.transpose(-2, -1)) / math.sqrt(self.d_k)
        attn_scores = attn_scores.masked_fill(mask == 0, -1e9)
        attn_probs = torch.softmax(attn_scores, dim=-1)
        #Зануление весов "снизу" там где софтмакс равномерен
        attn_probs = attn_probs.masked_fill(mask.transpose(-2, -1)==False, 0.0)

        output = torch.matmul(attn_probs, V)
        return output

    def split_heads(self, x):
        batch_size, seq_length, d_model = x.size()
        return x.view(batch_size, seq_length, self.num_heads, self.d_k).transpose(1, 2)

    def combine_heads(self, x):
        batch_size, _, seq_length, d_k = x.size()
        return x.transpose(1, 2).contiguous().view(batch_size, seq_length, self.d_model)

    def forward(self, Q, K, V, mask ):
        Q = self.split_heads(self.W_q(Q.to(device)))
        K = self.split_heads(self.W_k(K.to(device)))
        V = self.split_heads(self.W_v(V.to(device)))

        attn_output = self.scaled_dot_product_attention(Q, K, V, mask.to(device))
        output = self.W_o(self.combine_heads(attn_output))
        return output

# %%
class EncoderLayer(nn.Module):
    def __init__(self, d_model, num_heads, d_ff, dropout):
        super(EncoderLayer, self).__init__()
        self.norm1 = nn.BatchNorm1d(len_tokens, affine=False)
        self.norm2 = nn.BatchNorm1d(len_tokens, affine=False)
        self.dropout = nn.Dropout(dropout)
        self.multihead_attention = MultiHeadAttention(d_model, num_heads)
        self.feed_forward = nn.Sequential(
            nn.Linear(d_model, d_ff),
            nn.ReLU(),
            nn.Linear(d_ff, d_model),
            nn.BatchNorm1d(len_tokens)
        )

    def forward(self, src_embedded, src_mask):
        src_embedded_normalized = self.norm1(src_embedded.to(device))
        src_attention_output = self.multihead_attention(src_embedded_normalized, src_embedded_normalized, src_embedded_normalized, src_mask)

        src_attention_output = src_attention_output + src_embedded
        src_attention_output_normalized = self.norm2(src_attention_output)

        src_ff_output = self.feed_forward(src_attention_output_normalized)
        src_ff_output = self.dropout(src_ff_output)

        src_output = src_attention_output + src_ff_output
        return src_output

# %%
class Transformer_Encoder(nn.Module):
    def __init__(self, d_model, num_heads, num_layers, d_ff, dropout):
        super(Transformer_Encoder, self).__init__()
        self.embedding = nn.Embedding(vocabulary_size, d_model, padding_idx = 0)

        self.encoder_layers = nn.ModuleList([EncoderLayer(d_model, num_heads, d_ff, dropout) for _ in range(num_layers)])

        self.fc = nn.Linear(d_model, vocabulary_size, bias=False)
        self.dropout = nn.Dropout(dropout)
        self.Softmax = nn.Softmax(dim=-1)

    def generate_mask(self, src):
        src_mask = (src != 0).unsqueeze(1).unsqueeze(2)
        return src_mask

    def forward(self, seq):
        src_mask = self.generate_mask(seq)
        src_embedded = self.dropout(self.embedding(seq))

        for enc_layer in self.encoder_layers:
            src_embedded = enc_layer(src_embedded, src_mask)

        output = self.fc(src_embedded)
        return output

# %%
d_model = 24 ### 16, 24, 32 ...
num_heads = 8
num_layers = 3 ### Попробовать 2, 3, 12, 18, 24
d_ff = d_model * 5
dropout = 0.1
Transformer_Encoder = Transformer_Encoder(d_model, num_heads, num_layers, d_ff, dropout)

# %%
Transformer_Encoder.to(device)
# Out:
# Transformer_Encoder(
#   (embedding): Embedding(30018, 24, padding_idx=0)
#   (encoder_layers): ModuleList(
#     (0-2): 3 x EncoderLayer(
#       (norm1): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#       (norm2): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#       (multihead_attention): MultiHeadAttention(
#         (W_q): Linear(in_features=24, out_features=24, bias=False)
#         (W_k): Linear(in_features=24, out_features=24, bias=False)
#         (W_v): Linear(in_features=24, out_features=24, bias=False)
#         (W_o): Linear(in_features=24, out_features=24, bias=False)
#       )
#       (feed_forward): Sequential(
#         (0): Linear(in_features=24, out_features=120, bias=True)
#         (1): ReLU()
#         (2): Linear(in_features=120, out_features=24, bias=True)
#         (3): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (fc): Linear(in_features=24, out_features=30018, bias=False)
#   (dropout): Dropout(p=0.1, inplace=False)
#   (Softmax): Softmax(dim=-1)
# )

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(Transformer_Encoder.parameters(), lr=0.01, betas=(0.9, 0.98), eps=1e-9)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience=5, factor=0.9, verbose=True)
accuracy = torchmetrics.Accuracy(task="multiclass", num_classes = vocabulary_size, ignore_index=0).to(device)

Transformer_Encoder.train()
epoch_loss_avg = []
for epoch in range(500):
    losses = []  # список для сохранения всех loss внутри эпохи
    Accuracys = []  # список для сохранения всех loss внутри эпохи
    total_correct = 0  # переменная для сохранения общего числа правильных предсказаний
    total_samples = 0  # переменная для сохранения общего числа обработанных примеров
    for src_data, tgt_data in train_dataloader:
        src_data = src_data.to(device)
        tgt_data = tgt_data.to(device)
        optimizer.zero_grad()
        output = Transformer_Encoder(src_data)
        output_skill = output[:, 0, :]
        loss = criterion(output_skill, tgt_data)
        acc = accuracy(output_skill, tgt_data)
     #   acc = accuracy(output.contiguous().view(-1, vocabulary_size).argmax(dim=-1), tgt_data.contiguous().view(-1))
        losses.append(loss.item())  # добавляем значение loss в список
        Accuracys.append(acc.item())
        loss.backward()
        optimizer.step()

    epoch_loss = sum(losses) / len(losses)  # среднее значение loss для эпохи
    epoch_loss_avg.append(epoch_loss)
    scheduler.step(epoch_loss)  # Вставить scheduler.step() здесь
    epoch_Accuracy = sum(Accuracys) / len(Accuracys)  # среднее значение loss для эпохи
    print(f"Epoch: {epoch + 1}, Epoch_loss: {epoch_loss:.4f}, Accuracy: {epoch_Accuracy:.4f}" )
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:28: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn("The verbose parameter is deprecated. Please use get_last_lr() "
# Epoch: 1, Epoch_loss: 8.4664, Accuracy: 0.0122
# Epoch: 2, Epoch_loss: 7.3647, Accuracy: 0.0215
# Epoch: 3, Epoch_loss: 6.7294, Accuracy: 0.0303
# Epoch: 4, Epoch_loss: 6.2501, Accuracy: 0.0379
# Epoch: 5, Epoch_loss: 5.8776, Accuracy: 0.0458
# Epoch: 6, Epoch_loss: 5.5617, Accuracy: 0.0573
# Epoch: 7, Epoch_loss: 5.2804, Accuracy: 0.0707
# Epoch: 8, Epoch_loss: 5.0198, Accuracy: 0.0929
# Epoch: 9, Epoch_loss: 4.7722, Accuracy: 0.1148
# Epoch: 10, Epoch_loss: 4.5712, Accuracy: 0.1386
# Epoch: 11, Epoch_loss: 4.3641, Accuracy: 0.1652
# Epoch: 12, Epoch_loss: 4.1908, Accuracy: 0.1859
# Epoch: 13, Epoch_loss: 4.0616, Accuracy: 0.2070
# Epoch: 14, Epoch_loss: 3.9315, Accuracy: 0.2244
# Epoch: 15, Epoch_loss: 3.7901, Accuracy: 0.2429
# Epoch: 16, Epoch_loss: 3.6781, Accuracy: 0.2622
# Epoch: 17, Epoch_loss: 3.5864, Accuracy: 0.2779
# Epoch: 18, Epoch_loss: 3.5013, Accuracy: 0.2906
# Epoch: 19, Epoch_loss: 3.4330, Accuracy: 0.2969
# Epoch: 20, Epoch_loss: 3.3360, Accuracy: 0.3167
# Epoch: 21, Epoch_loss: 3.2703, Accuracy: 0.3263
# Epoch: 22, Epoch_loss: 3.2054, Accuracy: 0.3375
# Epoch: 23, Epoch_loss: 3.1320, Accuracy: 0.3475
# Epoch: 24, Epoch_loss: 3.0686, Accuracy: 0.3574
# Epoch: 25, Epoch_loss: 3.0639, Accuracy: 0.3583
# Epoch: 26, Epoch_loss: 3.0226, Accuracy: 0.3644
# Epoch: 27, Epoch_loss: 2.9814, Accuracy: 0.3726
# Epoch: 28, Epoch_loss: 2.8982, Accuracy: 0.3867
# Epoch: 29, Epoch_loss: 2.8548, Accuracy: 0.3949
# Epoch: 30, Epoch_loss: 2.8163, Accuracy: 0.3983
# Epoch: 31, Epoch_loss: 2.7917, Accuracy: 0.4011
# Epoch: 32, Epoch_loss: 2.7700, Accuracy: 0.4064
# Epoch: 33, Epoch_loss: 2.7191, Accuracy: 0.4180
# Epoch: 34, Epoch_loss: 2.6744, Accuracy: 0.4227
# Epoch: 35, Epoch_loss: 2.6649, Accuracy: 0.4244
# Epoch: 36, Epoch_loss: 2.6182, Accuracy: 0.4317
# Epoch: 37, Epoch_loss: 2.5992, Accuracy: 0.4359
# Epoch: 38, Epoch_loss: 2.5929, Accuracy: 0.4358
# Epoch: 39, Epoch_loss: 2.5912, Accuracy: 0.4364
# Epoch: 40, Epoch_loss: 2.5264, Accuracy: 0.4506
# Epoch: 41, Epoch_loss: 2.5021, Accuracy: 0.4508
# Epoch: 42, Epoch_loss: 2.5254, Accuracy: 0.4460
# Epoch: 43, Epoch_loss: 2.4813, Accuracy: 0.4564
# Epoch: 44, Epoch_loss: 2.4689, Accuracy: 0.4558
# Epoch: 45, Epoch_loss: 2.4309, Accuracy: 0.4644
# Epoch: 46, Epoch_loss: 2.4735, Accuracy: 0.4562
# Epoch: 47, Epoch_loss: 2.4690, Accuracy: 0.4564
# Epoch: 48, Epoch_loss: 2.3995, Accuracy: 0.4692
# Epoch: 49, Epoch_loss: 2.3437, Accuracy: 0.4787
# Epoch: 50, Epoch_loss: 2.3585, Accuracy: 0.4746
# Epoch: 51, Epoch_loss: 2.3446, Accuracy: 0.4798
# Epoch: 52, Epoch_loss: 2.3086, Accuracy: 0.4841
# Epoch: 53, Epoch_loss: 2.3086, Accuracy: 0.4848
# Epoch: 54, Epoch_loss: 2.2965, Accuracy: 0.4853
# Epoch: 55, Epoch_loss: 2.2891, Accuracy: 0.4892
# Epoch: 56, Epoch_loss: 2.3027, Accuracy: 0.4842
# Epoch: 57, Epoch_loss: 2.2848, Accuracy: 0.4895
# Epoch: 58, Epoch_loss: 2.2341, Accuracy: 0.4956
# Epoch: 59, Epoch_loss: 2.2235, Accuracy: 0.5016
# Epoch: 60, Epoch_loss: 2.2259, Accuracy: 0.4970
# Epoch: 61, Epoch_loss: 2.2383, Accuracy: 0.4983
# Epoch: 62, Epoch_loss: 2.2770, Accuracy: 0.4877
# Epoch: 63, Epoch_loss: 2.1876, Accuracy: 0.5058
# Epoch: 64, Epoch_loss: 2.1711, Accuracy: 0.5103
# Epoch: 65, Epoch_loss: 2.1738, Accuracy: 0.5056
# Epoch: 66, Epoch_loss: 2.1641, Accuracy: 0.5094
# Epoch: 67, Epoch_loss: 2.1526, Accuracy: 0.5088
# Epoch: 68, Epoch_loss: 2.1431, Accuracy: 0.5124
# Epoch: 69, Epoch_loss: 2.2871, Accuracy: 0.4883
# Epoch: 70, Epoch_loss: 2.1579, Accuracy: 0.5107
# Epoch: 71, Epoch_loss: 2.1365, Accuracy: 0.5145
# Epoch: 72, Epoch_loss: 2.1039, Accuracy: 0.5213
# Epoch: 73, Epoch_loss: 2.1505, Accuracy: 0.5101
# Epoch: 74, Epoch_loss: 2.1560, Accuracy: 0.5129
# Epoch: 75, Epoch_loss: 2.1408, Accuracy: 0.5132
# Epoch: 76, Epoch_loss: 2.1131, Accuracy: 0.5154
# Epoch: 77, Epoch_loss: 2.0870, Accuracy: 0.5229
# Epoch: 78, Epoch_loss: 2.0909, Accuracy: 0.5240
# Epoch: 79, Epoch_loss: 2.1150, Accuracy: 0.5142
# Epoch: 80, Epoch_loss: 2.1066, Accuracy: 0.5203
# Epoch: 81, Epoch_loss: 2.1539, Accuracy: 0.5088
# Epoch: 82, Epoch_loss: 2.1303, Accuracy: 0.5151
# Epoch: 83, Epoch_loss: 2.0488, Accuracy: 0.5303
# Epoch: 84, Epoch_loss: 2.0456, Accuracy: 0.5309
# Epoch: 85, Epoch_loss: 2.1104, Accuracy: 0.5193
# Epoch: 86, Epoch_loss: 2.1993, Accuracy: 0.5037
# Epoch: 87, Epoch_loss: 2.1760, Accuracy: 0.5074
# Epoch: 88, Epoch_loss: 2.0882, Accuracy: 0.5242
# Epoch: 89, Epoch_loss: 2.0485, Accuracy: 0.5324
# Epoch: 90, Epoch_loss: 2.0445, Accuracy: 0.5306
# Epoch: 91, Epoch_loss: 2.0595, Accuracy: 0.5277
# Epoch: 92, Epoch_loss: 2.0281, Accuracy: 0.5323
# Epoch: 93, Epoch_loss: 1.9883, Accuracy: 0.5412
# Epoch: 94, Epoch_loss: 1.9955, Accuracy: 0.5397
# Epoch: 95, Epoch_loss: 2.0149, Accuracy: 0.5351
# Epoch: 96, Epoch_loss: 2.0392, Accuracy: 0.5303
# Epoch: 97, Epoch_loss: 1.9922, Accuracy: 0.5391
# Epoch: 98, Epoch_loss: 1.9781, Accuracy: 0.5428
# Epoch: 99, Epoch_loss: 1.9666, Accuracy: 0.5431
# Epoch: 100, Epoch_loss: 1.9722, Accuracy: 0.5436
# Epoch: 101, Epoch_loss: 1.9619, Accuracy: 0.5446
# Epoch: 102, Epoch_loss: 1.9728, Accuracy: 0.5428
# Epoch: 103, Epoch_loss: 1.9675, Accuracy: 0.5428
# Epoch: 104, Epoch_loss: 1.9770, Accuracy: 0.5418
# Epoch: 105, Epoch_loss: 2.0017, Accuracy: 0.5368
# Epoch: 106, Epoch_loss: 2.0072, Accuracy: 0.5344
# Epoch: 107, Epoch_loss: 1.9318, Accuracy: 0.5539
# Epoch: 108, Epoch_loss: 1.9267, Accuracy: 0.5526
# Epoch: 109, Epoch_loss: 1.9195, Accuracy: 0.5523
# Epoch: 110, Epoch_loss: 1.9390, Accuracy: 0.5492
# Epoch: 111, Epoch_loss: 1.9578, Accuracy: 0.5455
# Epoch: 112, Epoch_loss: 1.9528, Accuracy: 0.5482
# Epoch: 113, Epoch_loss: 1.9475, Accuracy: 0.5465
# Epoch: 114, Epoch_loss: 1.8961, Accuracy: 0.5578
# Epoch: 115, Epoch_loss: 1.9132, Accuracy: 0.5556
# Epoch: 116, Epoch_loss: 1.9376, Accuracy: 0.5501
# Epoch: 117, Epoch_loss: 1.9451, Accuracy: 0.5485
# Epoch: 118, Epoch_loss: 1.9899, Accuracy: 0.5429
# Epoch: 119, Epoch_loss: 1.9150, Accuracy: 0.5522
# Epoch: 120, Epoch_loss: 1.8910, Accuracy: 0.5601
# Epoch: 121, Epoch_loss: 1.9087, Accuracy: 0.5557
# Epoch: 122, Epoch_loss: 1.9340, Accuracy: 0.5498
# Epoch: 123, Epoch_loss: 1.8806, Accuracy: 0.5569
# Epoch: 124, Epoch_loss: 1.8779, Accuracy: 0.5609
# Epoch: 125, Epoch_loss: 1.9444, Accuracy: 0.5474
# Epoch: 126, Epoch_loss: 1.9136, Accuracy: 0.5555
# Epoch: 127, Epoch_loss: 1.8802, Accuracy: 0.5610
# Epoch: 128, Epoch_loss: 1.8760, Accuracy: 0.5635
# Epoch: 129, Epoch_loss: 1.8623, Accuracy: 0.5628
# Epoch: 130, Epoch_loss: 1.8927, Accuracy: 0.5560
# Epoch: 131, Epoch_loss: 1.9152, Accuracy: 0.5536
# Epoch: 132, Epoch_loss: 1.9940, Accuracy: 0.5371
# Epoch: 133, Epoch_loss: 1.8904, Accuracy: 0.5571
# Epoch: 134, Epoch_loss: 1.8848, Accuracy: 0.5595
# Epoch: 135, Epoch_loss: 2.0104, Accuracy: 0.5372
# Epoch: 136, Epoch_loss: 1.9136, Accuracy: 0.5539
# Epoch: 137, Epoch_loss: 1.8052, Accuracy: 0.5753
# Epoch: 138, Epoch_loss: 1.7962, Accuracy: 0.5775
# Epoch: 139, Epoch_loss: 1.8269, Accuracy: 0.5723
# Epoch: 140, Epoch_loss: 1.7995, Accuracy: 0.5759
# Epoch: 141, Epoch_loss: 1.8156, Accuracy: 0.5718
# Epoch: 142, Epoch_loss: 1.7958, Accuracy: 0.5779
# Epoch: 143, Epoch_loss: 1.7840, Accuracy: 0.5798
# Epoch: 144, Epoch_loss: 1.8008, Accuracy: 0.5731
# Epoch: 145, Epoch_loss: 1.7929, Accuracy: 0.5765
# Epoch: 146, Epoch_loss: 1.7701, Accuracy: 0.5806
# Epoch: 147, Epoch_loss: 1.7906, Accuracy: 0.5776
# Epoch: 148, Epoch_loss: 1.7740, Accuracy: 0.5792
# Epoch: 149, Epoch_loss: 1.7704, Accuracy: 0.5812
# Epoch: 150, Epoch_loss: 1.8672, Accuracy: 0.5613
# Epoch: 151, Epoch_loss: 1.8470, Accuracy: 0.5673
# Epoch: 152, Epoch_loss: 1.7957, Accuracy: 0.5754
# Epoch: 153, Epoch_loss: 1.7141, Accuracy: 0.5926
# Epoch: 154, Epoch_loss: 1.7130, Accuracy: 0.5949
# Epoch: 155, Epoch_loss: 1.7298, Accuracy: 0.5890
# Epoch: 156, Epoch_loss: 1.6987, Accuracy: 0.5962
# Epoch: 157, Epoch_loss: 1.6985, Accuracy: 0.5926
# Epoch: 158, Epoch_loss: 1.7069, Accuracy: 0.5931
# Epoch: 159, Epoch_loss: 1.6998, Accuracy: 0.5957
# Epoch: 160, Epoch_loss: 1.7545, Accuracy: 0.5866
# Epoch: 161, Epoch_loss: 1.7299, Accuracy: 0.5897
# Epoch: 162, Epoch_loss: 1.6891, Accuracy: 0.5969
# Epoch: 163, Epoch_loss: 1.7174, Accuracy: 0.5906
# Epoch: 164, Epoch_loss: 1.6966, Accuracy: 0.5970
# Epoch: 165, Epoch_loss: 1.7145, Accuracy: 0.5916
# Epoch: 166, Epoch_loss: 1.7086, Accuracy: 0.5936
# Epoch: 167, Epoch_loss: 1.6836, Accuracy: 0.5975
# Epoch: 168, Epoch_loss: 1.7103, Accuracy: 0.5929
# Epoch: 169, Epoch_loss: 1.7166, Accuracy: 0.5905
# Epoch: 170, Epoch_loss: 1.7044, Accuracy: 0.5948
# Epoch: 171, Epoch_loss: 1.7017, Accuracy: 0.5962
# Epoch: 172, Epoch_loss: 1.6750, Accuracy: 0.5982
# Epoch: 173, Epoch_loss: 1.7639, Accuracy: 0.5845
# Epoch: 174, Epoch_loss: 1.7859, Accuracy: 0.5787
# Epoch: 175, Epoch_loss: 1.7323, Accuracy: 0.5900
# Epoch: 176, Epoch_loss: 1.6903, Accuracy: 0.5958
# Epoch: 177, Epoch_loss: 1.6787, Accuracy: 0.6009
# Epoch: 178, Epoch_loss: 1.6760, Accuracy: 0.5982
# Epoch: 179, Epoch_loss: 1.6522, Accuracy: 0.6067
# Epoch: 180, Epoch_loss: 1.6450, Accuracy: 0.6074
# Epoch: 181, Epoch_loss: 1.6317, Accuracy: 0.6095
# Epoch: 182, Epoch_loss: 1.6215, Accuracy: 0.6110
# Epoch: 183, Epoch_loss: 1.6483, Accuracy: 0.6083
# Epoch: 184, Epoch_loss: 1.6161, Accuracy: 0.6128
# Epoch: 185, Epoch_loss: 1.6309, Accuracy: 0.6097
# Epoch: 186, Epoch_loss: 1.6330, Accuracy: 0.6055
# Epoch: 187, Epoch_loss: 1.6269, Accuracy: 0.6094
# Epoch: 188, Epoch_loss: 1.6414, Accuracy: 0.6102
# Epoch: 189, Epoch_loss: 1.6333, Accuracy: 0.6067
# Epoch: 190, Epoch_loss: 1.6339, Accuracy: 0.6044
# Epoch: 191, Epoch_loss: 1.5802, Accuracy: 0.6199
# Epoch: 192, Epoch_loss: 1.5673, Accuracy: 0.6247
# Epoch: 193, Epoch_loss: 1.5852, Accuracy: 0.6174
# Epoch: 194, Epoch_loss: 1.6033, Accuracy: 0.6141
# Epoch: 195, Epoch_loss: 1.6040, Accuracy: 0.6138
# Epoch: 196, Epoch_loss: 1.5834, Accuracy: 0.6195
# Epoch: 197, Epoch_loss: 1.5758, Accuracy: 0.6194
# Epoch: 198, Epoch_loss: 1.5804, Accuracy: 0.6201
# Epoch: 199, Epoch_loss: 1.5476, Accuracy: 0.6249
# Epoch: 200, Epoch_loss: 1.5479, Accuracy: 0.6280
# Epoch: 201, Epoch_loss: 1.5493, Accuracy: 0.6265
# Epoch: 202, Epoch_loss: 1.5480, Accuracy: 0.6275
# Epoch: 203, Epoch_loss: 1.5367, Accuracy: 0.6292
# Epoch: 204, Epoch_loss: 1.5227, Accuracy: 0.6299
# Epoch: 205, Epoch_loss: 1.5450, Accuracy: 0.6277
# Epoch: 206, Epoch_loss: 1.5365, Accuracy: 0.6282
# Epoch: 207, Epoch_loss: 1.5288, Accuracy: 0.6312
# Epoch: 208, Epoch_loss: 1.5349, Accuracy: 0.6282
# Epoch: 209, Epoch_loss: 1.5452, Accuracy: 0.6265
# Epoch: 210, Epoch_loss: 1.5283, Accuracy: 0.6292
# Epoch: 211, Epoch_loss: 1.5031, Accuracy: 0.6333
# Epoch: 212, Epoch_loss: 1.5015, Accuracy: 0.6381
# Epoch: 213, Epoch_loss: 1.5117, Accuracy: 0.6332
# Epoch: 214, Epoch_loss: 1.4977, Accuracy: 0.6353
# Epoch: 215, Epoch_loss: 1.4933, Accuracy: 0.6386
# Epoch: 216, Epoch_loss: 1.4988, Accuracy: 0.6350
# Epoch: 217, Epoch_loss: 1.4921, Accuracy: 0.6387
# Epoch: 218, Epoch_loss: 1.4916, Accuracy: 0.6369
# Epoch: 219, Epoch_loss: 1.5031, Accuracy: 0.6357
# Epoch: 220, Epoch_loss: 1.4935, Accuracy: 0.6363
# Epoch: 221, Epoch_loss: 1.4941, Accuracy: 0.6368
# Epoch: 222, Epoch_loss: 1.5312, Accuracy: 0.6296
# Epoch: 223, Epoch_loss: 1.4891, Accuracy: 0.6383
# Epoch: 224, Epoch_loss: 1.5023, Accuracy: 0.6343
# Epoch: 225, Epoch_loss: 1.4865, Accuracy: 0.6383
# Epoch: 226, Epoch_loss: 1.4923, Accuracy: 0.6378
# Epoch: 227, Epoch_loss: 1.4955, Accuracy: 0.6353
# Epoch: 228, Epoch_loss: 1.5035, Accuracy: 0.6352
# Epoch: 229, Epoch_loss: 1.4927, Accuracy: 0.6370
# Epoch: 230, Epoch_loss: 1.5174, Accuracy: 0.6316
# Epoch: 231, Epoch_loss: 1.4942, Accuracy: 0.6361
# Epoch: 232, Epoch_loss: 1.4786, Accuracy: 0.6411
# Epoch: 233, Epoch_loss: 1.4529, Accuracy: 0.6464
# Epoch: 234, Epoch_loss: 1.4629, Accuracy: 0.6407
# Epoch: 235, Epoch_loss: 1.4646, Accuracy: 0.6433
# Epoch: 236, Epoch_loss: 1.4629, Accuracy: 0.6442
# Epoch: 237, Epoch_loss: 1.4546, Accuracy: 0.6468
# Epoch: 238, Epoch_loss: 1.4726, Accuracy: 0.6416
# Epoch: 239, Epoch_loss: 1.4561, Accuracy: 0.6446
# Epoch: 240, Epoch_loss: 1.4465, Accuracy: 0.6467
# Epoch: 241, Epoch_loss: 1.4253, Accuracy: 0.6522
# Epoch: 242, Epoch_loss: 1.4254, Accuracy: 0.6518
# Epoch: 243, Epoch_loss: 1.4421, Accuracy: 0.6490
# Epoch: 244, Epoch_loss: 1.4351, Accuracy: 0.6471
# Epoch: 245, Epoch_loss: 1.4108, Accuracy: 0.6549
# Epoch: 246, Epoch_loss: 1.4302, Accuracy: 0.6498
# Epoch: 247, Epoch_loss: 1.4295, Accuracy: 0.6520
# Epoch: 248, Epoch_loss: 1.4375, Accuracy: 0.6500
# Epoch: 249, Epoch_loss: 1.4369, Accuracy: 0.6515
# Epoch: 250, Epoch_loss: 1.4469, Accuracy: 0.6475
# Epoch: 251, Epoch_loss: 1.4340, Accuracy: 0.6506
# Epoch: 252, Epoch_loss: 1.4101, Accuracy: 0.6551
# Epoch: 253, Epoch_loss: 1.4164, Accuracy: 0.6515
# Epoch: 254, Epoch_loss: 1.4046, Accuracy: 0.6565
# Epoch: 255, Epoch_loss: 1.3970, Accuracy: 0.6562
# Epoch: 256, Epoch_loss: 1.4017, Accuracy: 0.6574
# Epoch: 257, Epoch_loss: 1.3993, Accuracy: 0.6566
# Epoch: 258, Epoch_loss: 1.3975, Accuracy: 0.6570
# Epoch: 259, Epoch_loss: 1.4020, Accuracy: 0.6580
# Epoch: 260, Epoch_loss: 1.3958, Accuracy: 0.6587
# Epoch: 261, Epoch_loss: 1.4090, Accuracy: 0.6573
# Epoch: 262, Epoch_loss: 1.4055, Accuracy: 0.6579
# Epoch: 263, Epoch_loss: 1.4035, Accuracy: 0.6545
# Epoch: 264, Epoch_loss: 1.4071, Accuracy: 0.6553
# Epoch: 265, Epoch_loss: 1.3881, Accuracy: 0.6596
# Epoch: 266, Epoch_loss: 1.3985, Accuracy: 0.6562
# Epoch: 267, Epoch_loss: 1.3979, Accuracy: 0.6574
# Epoch: 268, Epoch_loss: 1.4128, Accuracy: 0.6571
# Epoch: 269, Epoch_loss: 1.4034, Accuracy: 0.6564
# Epoch: 270, Epoch_loss: 1.4065, Accuracy: 0.6570
# Epoch: 271, Epoch_loss: 1.4010, Accuracy: 0.6573
# Epoch: 272, Epoch_loss: 1.3786, Accuracy: 0.6622
# Epoch: 273, Epoch_loss: 1.3755, Accuracy: 0.6632
# Epoch: 274, Epoch_loss: 1.3814, Accuracy: 0.6618
# Epoch: 275, Epoch_loss: 1.3880, Accuracy: 0.6597
# Epoch: 276, Epoch_loss: 1.3880, Accuracy: 0.6603
# Epoch: 277, Epoch_loss: 1.3796, Accuracy: 0.6622
# Epoch: 278, Epoch_loss: 1.3625, Accuracy: 0.6665
# Epoch: 279, Epoch_loss: 1.3794, Accuracy: 0.6633
# Epoch: 280, Epoch_loss: 1.3725, Accuracy: 0.6652
# Epoch: 281, Epoch_loss: 1.3812, Accuracy: 0.6621
# Epoch: 282, Epoch_loss: 1.3752, Accuracy: 0.6657
# Epoch: 283, Epoch_loss: 1.3749, Accuracy: 0.6624
# Epoch: 284, Epoch_loss: 1.3781, Accuracy: 0.6612
# Epoch: 285, Epoch_loss: 1.3642, Accuracy: 0.6654
# Epoch: 286, Epoch_loss: 1.3522, Accuracy: 0.6687
# Epoch: 287, Epoch_loss: 1.3561, Accuracy: 0.6661
# Epoch: 288, Epoch_loss: 1.3696, Accuracy: 0.6611
# Epoch: 289, Epoch_loss: 1.3443, Accuracy: 0.6707
# Epoch: 290, Epoch_loss: 1.3524, Accuracy: 0.6668
# Epoch: 291, Epoch_loss: 1.3535, Accuracy: 0.6690
# Epoch: 292, Epoch_loss: 1.3521, Accuracy: 0.6687
# Epoch: 293, Epoch_loss: 1.3556, Accuracy: 0.6697
# Epoch: 294, Epoch_loss: 1.3546, Accuracy: 0.6651
# Epoch: 295, Epoch_loss: 1.3584, Accuracy: 0.6671
# Epoch: 296, Epoch_loss: 1.3401, Accuracy: 0.6706
# Epoch: 297, Epoch_loss: 1.3352, Accuracy: 0.6737
# Epoch: 298, Epoch_loss: 1.3421, Accuracy: 0.6731
# Epoch: 299, Epoch_loss: 1.3317, Accuracy: 0.6723
# Epoch: 300, Epoch_loss: 1.3472, Accuracy: 0.6692
# Epoch: 301, Epoch_loss: 1.3550, Accuracy: 0.6670
# Epoch: 302, Epoch_loss: 1.3431, Accuracy: 0.6688
# Epoch: 303, Epoch_loss: 1.3265, Accuracy: 0.6717
# Epoch: 304, Epoch_loss: 1.3416, Accuracy: 0.6728
# Epoch: 305, Epoch_loss: 1.3375, Accuracy: 0.6708
# Epoch: 306, Epoch_loss: 1.3258, Accuracy: 0.6744
# Epoch: 307, Epoch_loss: 1.3430, Accuracy: 0.6695
# Epoch: 308, Epoch_loss: 1.3352, Accuracy: 0.6726
# Epoch: 309, Epoch_loss: 1.3289, Accuracy: 0.6727
# Epoch: 310, Epoch_loss: 1.3357, Accuracy: 0.6691
# Epoch: 311, Epoch_loss: 1.3445, Accuracy: 0.6696
# Epoch: 312, Epoch_loss: 1.3279, Accuracy: 0.6730
# Epoch: 313, Epoch_loss: 1.3308, Accuracy: 0.6726
# Epoch: 314, Epoch_loss: 1.3274, Accuracy: 0.6725
# Epoch: 315, Epoch_loss: 1.3201, Accuracy: 0.6746
# Epoch: 316, Epoch_loss: 1.3198, Accuracy: 0.6758
# Epoch: 317, Epoch_loss: 1.3170, Accuracy: 0.6772
# Epoch: 318, Epoch_loss: 1.3239, Accuracy: 0.6743
# Epoch: 319, Epoch_loss: 1.3117, Accuracy: 0.6782
# Epoch: 320, Epoch_loss: 1.3079, Accuracy: 0.6788
# Epoch: 321, Epoch_loss: 1.3122, Accuracy: 0.6771
# Epoch: 322, Epoch_loss: 1.3226, Accuracy: 0.6742
# Epoch: 323, Epoch_loss: 1.3234, Accuracy: 0.6748
# Epoch: 324, Epoch_loss: 1.3116, Accuracy: 0.6755
# Epoch: 325, Epoch_loss: 1.3116, Accuracy: 0.6750
# Epoch: 326, Epoch_loss: 1.3196, Accuracy: 0.6732
# Epoch: 327, Epoch_loss: 1.3018, Accuracy: 0.6795
# Epoch: 328, Epoch_loss: 1.3044, Accuracy: 0.6786
# Epoch: 329, Epoch_loss: 1.2969, Accuracy: 0.6790
# Epoch: 330, Epoch_loss: 1.2947, Accuracy: 0.6822
# Epoch: 331, Epoch_loss: 1.2979, Accuracy: 0.6780
# Epoch: 332, Epoch_loss: 1.2968, Accuracy: 0.6785
# Epoch: 333, Epoch_loss: 1.2969, Accuracy: 0.6804
# Epoch: 334, Epoch_loss: 1.3057, Accuracy: 0.6763
# Epoch: 335, Epoch_loss: 1.3002, Accuracy: 0.6788
# Epoch: 336, Epoch_loss: 1.2957, Accuracy: 0.6805
# Epoch: 337, Epoch_loss: 1.2786, Accuracy: 0.6840
# Epoch: 338, Epoch_loss: 1.2891, Accuracy: 0.6828
# Epoch: 339, Epoch_loss: 1.2804, Accuracy: 0.6840
# Epoch: 340, Epoch_loss: 1.2851, Accuracy: 0.6836
# Epoch: 341, Epoch_loss: 1.2835, Accuracy: 0.6837
# Epoch: 342, Epoch_loss: 1.3006, Accuracy: 0.6786
# Epoch: 343, Epoch_loss: 1.2866, Accuracy: 0.6842
# Epoch: 344, Epoch_loss: 1.2693, Accuracy: 0.6852
# Epoch: 345, Epoch_loss: 1.2642, Accuracy: 0.6872
# Epoch: 346, Epoch_loss: 1.2663, Accuracy: 0.6877
# Epoch: 347, Epoch_loss: 1.2739, Accuracy: 0.6850
# Epoch: 348, Epoch_loss: 1.2726, Accuracy: 0.6852
# Epoch: 349, Epoch_loss: 1.2853, Accuracy: 0.6859
# Epoch: 350, Epoch_loss: 1.2759, Accuracy: 0.6848
# Epoch: 351, Epoch_loss: 1.2721, Accuracy: 0.6881
# Epoch: 352, Epoch_loss: 1.2654, Accuracy: 0.6891
# Epoch: 353, Epoch_loss: 1.2683, Accuracy: 0.6887
# Epoch: 354, Epoch_loss: 1.2678, Accuracy: 0.6880
# Epoch: 355, Epoch_loss: 1.2666, Accuracy: 0.6880
# Epoch: 356, Epoch_loss: 1.2664, Accuracy: 0.6875
# Epoch: 357, Epoch_loss: 1.2596, Accuracy: 0.6877
# Epoch: 358, Epoch_loss: 1.2602, Accuracy: 0.6907
# Epoch: 359, Epoch_loss: 1.2622, Accuracy: 0.6866
# Epoch: 360, Epoch_loss: 1.2641, Accuracy: 0.6868
# Epoch: 361, Epoch_loss: 1.2599, Accuracy: 0.6876
# Epoch: 362, Epoch_loss: 1.2620, Accuracy: 0.6913
# Epoch: 363, Epoch_loss: 1.2653, Accuracy: 0.6847
# Epoch: 364, Epoch_loss: 1.2518, Accuracy: 0.6907
# Epoch: 365, Epoch_loss: 1.2520, Accuracy: 0.6888
# Epoch: 366, Epoch_loss: 1.2446, Accuracy: 0.6912
# Epoch: 367, Epoch_loss: 1.2467, Accuracy: 0.6909
# Epoch: 368, Epoch_loss: 1.2562, Accuracy: 0.6911
# Epoch: 369, Epoch_loss: 1.2516, Accuracy: 0.6895
# Epoch: 370, Epoch_loss: 1.2543, Accuracy: 0.6899
# Epoch: 371, Epoch_loss: 1.2451, Accuracy: 0.6900
# Epoch: 372, Epoch_loss: 1.2425, Accuracy: 0.6918
# Epoch: 373, Epoch_loss: 1.2435, Accuracy: 0.6902
# Epoch: 374, Epoch_loss: 1.2540, Accuracy: 0.6897
# Epoch: 375, Epoch_loss: 1.2499, Accuracy: 0.6914
# Epoch: 376, Epoch_loss: 1.2511, Accuracy: 0.6907
# Epoch: 377, Epoch_loss: 1.2473, Accuracy: 0.6924
# Epoch: 378, Epoch_loss: 1.2458, Accuracy: 0.6933
# Epoch: 379, Epoch_loss: 1.2385, Accuracy: 0.6939
# Epoch: 380, Epoch_loss: 1.2371, Accuracy: 0.6944
# Epoch: 381, Epoch_loss: 1.2381, Accuracy: 0.6938
# Epoch: 382, Epoch_loss: 1.2387, Accuracy: 0.6939
# Epoch: 383, Epoch_loss: 1.2367, Accuracy: 0.6934
# Epoch: 384, Epoch_loss: 1.2476, Accuracy: 0.6912
# Epoch: 385, Epoch_loss: 1.2393, Accuracy: 0.6949
# Epoch: 386, Epoch_loss: 1.2313, Accuracy: 0.6947
# Epoch: 387, Epoch_loss: 1.2418, Accuracy: 0.6929
# Epoch: 388, Epoch_loss: 1.2366, Accuracy: 0.6937
# Epoch: 389, Epoch_loss: 1.2425, Accuracy: 0.6921
# Epoch: 390, Epoch_loss: 1.2297, Accuracy: 0.6950
# Epoch: 391, Epoch_loss: 1.2397, Accuracy: 0.6933
# Epoch: 392, Epoch_loss: 1.2314, Accuracy: 0.6943
# Epoch: 393, Epoch_loss: 1.2374, Accuracy: 0.6937
# Epoch: 394, Epoch_loss: 1.2315, Accuracy: 0.6951
# Epoch: 395, Epoch_loss: 1.2302, Accuracy: 0.6949
# Epoch: 396, Epoch_loss: 1.2413, Accuracy: 0.6938
# Epoch: 397, Epoch_loss: 1.2385, Accuracy: 0.6921
# Epoch: 398, Epoch_loss: 1.2365, Accuracy: 0.6952
# Epoch: 399, Epoch_loss: 1.2269, Accuracy: 0.6961
# Epoch: 400, Epoch_loss: 1.2399, Accuracy: 0.6945
# Epoch: 401, Epoch_loss: 1.2245, Accuracy: 0.6945
# Epoch: 402, Epoch_loss: 1.2308, Accuracy: 0.6932
# Epoch: 403, Epoch_loss: 1.2301, Accuracy: 0.6967
# Epoch: 404, Epoch_loss: 1.2317, Accuracy: 0.6941
# Epoch: 405, Epoch_loss: 1.2188, Accuracy: 0.6978
# Epoch: 406, Epoch_loss: 1.2271, Accuracy: 0.6963
# Epoch: 407, Epoch_loss: 1.2300, Accuracy: 0.6951
# Epoch: 408, Epoch_loss: 1.2343, Accuracy: 0.6943
# Epoch: 409, Epoch_loss: 1.2217, Accuracy: 0.6964
# Epoch: 410, Epoch_loss: 1.2295, Accuracy: 0.6937
# Epoch: 411, Epoch_loss: 1.2424, Accuracy: 0.6929
# Epoch: 412, Epoch_loss: 1.2234, Accuracy: 0.6966
# Epoch: 413, Epoch_loss: 1.2236, Accuracy: 0.6975
# Epoch: 414, Epoch_loss: 1.2205, Accuracy: 0.6988
# Epoch: 415, Epoch_loss: 1.2239, Accuracy: 0.6977
# Epoch: 416, Epoch_loss: 1.2239, Accuracy: 0.6963
# Epoch: 417, Epoch_loss: 1.2304, Accuracy: 0.6937
# Epoch: 418, Epoch_loss: 1.2132, Accuracy: 0.6986
# Epoch: 419, Epoch_loss: 1.2170, Accuracy: 0.6964
# Epoch: 420, Epoch_loss: 1.2200, Accuracy: 0.6986
# Epoch: 421, Epoch_loss: 1.2160, Accuracy: 0.6996
# Epoch: 422, Epoch_loss: 1.2211, Accuracy: 0.6983
# Epoch: 423, Epoch_loss: 1.2152, Accuracy: 0.6994
# Epoch: 424, Epoch_loss: 1.2209, Accuracy: 0.6985
# Epoch: 425, Epoch_loss: 1.2094, Accuracy: 0.6993
# Epoch: 426, Epoch_loss: 1.2141, Accuracy: 0.6993
# Epoch: 427, Epoch_loss: 1.1998, Accuracy: 0.7038
# Epoch: 428, Epoch_loss: 1.2017, Accuracy: 0.7038
# Epoch: 429, Epoch_loss: 1.2104, Accuracy: 0.7003
# Epoch: 430, Epoch_loss: 1.2126, Accuracy: 0.7020
# Epoch: 431, Epoch_loss: 1.2123, Accuracy: 0.7010
# Epoch: 432, Epoch_loss: 1.2089, Accuracy: 0.7006
# Epoch: 433, Epoch_loss: 1.2114, Accuracy: 0.7008
# Epoch: 434, Epoch_loss: 1.2015, Accuracy: 0.7013
# Epoch: 435, Epoch_loss: 1.2015, Accuracy: 0.7024
# Epoch: 436, Epoch_loss: 1.1986, Accuracy: 0.7031
# Epoch: 437, Epoch_loss: 1.1963, Accuracy: 0.7037
# Epoch: 438, Epoch_loss: 1.2044, Accuracy: 0.7027
# Epoch: 439, Epoch_loss: 1.1991, Accuracy: 0.7019
# Epoch: 440, Epoch_loss: 1.1997, Accuracy: 0.7019
# Epoch: 441, Epoch_loss: 1.2001, Accuracy: 0.7025
# Epoch: 442, Epoch_loss: 1.2058, Accuracy: 0.7006
# Epoch: 443, Epoch_loss: 1.2004, Accuracy: 0.7025
# Epoch: 444, Epoch_loss: 1.2008, Accuracy: 0.7031
# Epoch: 445, Epoch_loss: 1.2031, Accuracy: 0.7032
# Epoch: 446, Epoch_loss: 1.1954, Accuracy: 0.7031
# Epoch: 447, Epoch_loss: 1.1946, Accuracy: 0.7050
# Epoch: 448, Epoch_loss: 1.1948, Accuracy: 0.7031
# Epoch: 449, Epoch_loss: 1.1891, Accuracy: 0.7053
# Epoch: 450, Epoch_loss: 1.1882, Accuracy: 0.7064
# Epoch: 451, Epoch_loss: 1.1946, Accuracy: 0.7047
# Epoch: 452, Epoch_loss: 1.1901, Accuracy: 0.7057
# Epoch: 453, Epoch_loss: 1.1988, Accuracy: 0.7020
# Epoch: 454, Epoch_loss: 1.1970, Accuracy: 0.7036
# Epoch: 455, Epoch_loss: 1.2020, Accuracy: 0.7008
# Epoch: 456, Epoch_loss: 1.1967, Accuracy: 0.7030
# Epoch: 457, Epoch_loss: 1.1947, Accuracy: 0.7031
# Epoch: 458, Epoch_loss: 1.1895, Accuracy: 0.7065
# Epoch: 459, Epoch_loss: 1.1911, Accuracy: 0.7041
# Epoch: 460, Epoch_loss: 1.1911, Accuracy: 0.7049
# Epoch: 461, Epoch_loss: 1.1955, Accuracy: 0.7046
# Epoch: 462, Epoch_loss: 1.1876, Accuracy: 0.7060
# Epoch: 463, Epoch_loss: 1.1900, Accuracy: 0.7059
# Epoch: 464, Epoch_loss: 1.1884, Accuracy: 0.7065
# Epoch: 465, Epoch_loss: 1.1949, Accuracy: 0.7052
# Epoch: 466, Epoch_loss: 1.1905, Accuracy: 0.7039
# Epoch: 467, Epoch_loss: 1.1917, Accuracy: 0.7060
# Epoch: 468, Epoch_loss: 1.1999, Accuracy: 0.7050
# Epoch: 469, Epoch_loss: 1.1820, Accuracy: 0.7064
# Epoch: 470, Epoch_loss: 1.1851, Accuracy: 0.7059
# Epoch: 471, Epoch_loss: 1.1876, Accuracy: 0.7061
# Epoch: 472, Epoch_loss: 1.1832, Accuracy: 0.7075
# Epoch: 473, Epoch_loss: 1.1870, Accuracy: 0.7025
# Epoch: 474, Epoch_loss: 1.1897, Accuracy: 0.7052
# Epoch: 475, Epoch_loss: 1.1843, Accuracy: 0.7067
# Epoch: 476, Epoch_loss: 1.1881, Accuracy: 0.7080
# Epoch: 477, Epoch_loss: 1.1681, Accuracy: 0.7098
# Epoch: 478, Epoch_loss: 1.1754, Accuracy: 0.7081
# Epoch: 479, Epoch_loss: 1.1799, Accuracy: 0.7089
# Epoch: 480, Epoch_loss: 1.1841, Accuracy: 0.7063
# Epoch: 481, Epoch_loss: 1.1809, Accuracy: 0.7080
# Epoch: 482, Epoch_loss: 1.1867, Accuracy: 0.7063
# Epoch: 483, Epoch_loss: 1.1895, Accuracy: 0.7059
# Epoch: 484, Epoch_loss: 1.1834, Accuracy: 0.7092
# Epoch: 485, Epoch_loss: 1.1816, Accuracy: 0.7092
# Epoch: 486, Epoch_loss: 1.1808, Accuracy: 0.7101
# Epoch: 487, Epoch_loss: 1.1807, Accuracy: 0.7071
# Epoch: 488, Epoch_loss: 1.1804, Accuracy: 0.7065
# Epoch: 489, Epoch_loss: 1.1740, Accuracy: 0.7099
# Epoch: 490, Epoch_loss: 1.1777, Accuracy: 0.7093
# Epoch: 491, Epoch_loss: 1.1739, Accuracy: 0.7115
# Epoch: 492, Epoch_loss: 1.1659, Accuracy: 0.7099
# Epoch: 493, Epoch_loss: 1.1797, Accuracy: 0.7077
# Epoch: 494, Epoch_loss: 1.1719, Accuracy: 0.7116
# Epoch: 495, Epoch_loss: 1.1744, Accuracy: 0.7089
# Epoch: 496, Epoch_loss: 1.1802, Accuracy: 0.7085
# Epoch: 497, Epoch_loss: 1.1747, Accuracy: 0.7085
# Epoch: 498, Epoch_loss: 1.1670, Accuracy: 0.7117
# Epoch: 499, Epoch_loss: 1.1707, Accuracy: 0.7112
# Epoch: 500, Epoch_loss: 1.1691, Accuracy: 0.7114

# %%
plt.plot(epoch_loss_avg)

# %%
input_data = []
for i in range(vocabulary_size):
    input_data.append(i)

# %%
input_data = torch.tensor(input_data)

# %%
import torch
import torch.nn as nn

# Assume you have a model called `my_model` with an embedding layer
embedding_layer = Transformer_Encoder.embedding  # Get the embedding layer

# Create a sample input data
#input_data = torch.tensor([1, 2, 3, 4, 5])  # example input data

# Pass the input data through the embedding layer
embeddings = embedding_layer(input_data.to(device))

# Now you have the embeddings for the input data
print(embeddings)
# Out:
# tensor([[ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ...,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [-5.2922e-03, -1.0354e-03, -2.9039e-01,  ...,  2.1554e-01,
#           4.7286e-01,  2.4485e-01],
#         [-2.0752e+00,  2.4649e+00,  2.8302e+00,  ...,  1.0274e+00,
#          -8.0729e-01,  8.6669e-01],
#         ...,
#         [-1.2318e+00, -2.6171e-01, -1.8578e+00,  ...,  1.0886e+00,
#           3.8773e+00,  7.2718e-01],
#         [-1.6757e-01, -1.3390e-01,  1.1636e+00,  ..., -4.1233e-01,
#           5.2136e-02,  5.1510e-01],
#         [-1.1516e+00, -3.0170e+00, -8.7637e-01,  ..., -2.9827e+00,
#          -2.3400e+00, -2.1130e+00]], device='cuda:0',
#        grad_fn=<EmbeddingBackward0>)

# %%
# !pip install hdbscan
# Out:
# Requirement already satisfied: hdbscan in /usr/local/lib/python3.10/dist-packages (0.8.33)
# Requirement already satisfied: cython<3,>=0.27 in /usr/local/lib/python3.10/dist-packages (from hdbscan) (0.29.37)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from hdbscan) (1.25.2)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan) (1.11.4)
# Requirement already satisfied: scikit-learn>=0.20 in /usr/local/lib/python3.10/dist-packages (from hdbscan) (1.2.2)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20->hdbscan) (3.4.0)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
import hdbscan


embeddings = embeddings.cpu()
# Загрузка эмбеддингов слов
#embeddings = embeddings_np
embeddings_np = embeddings.detach().numpy()

# Сокращение размерности с помощью t-SNE
tsne = TSNE(n_components=3, perplexity=3)
embeddings_tsne = tsne.fit_transform(embeddings_np)



# Кластеризация с помощью HDBSCAN
clusterer = hdbscan.HDBSCAN(min_cluster_size=6)
clusters = clusterer.fit_predict(embeddings_tsne)

# Визуализация результатов
plt.scatter(embeddings_tsne[:, 0], embeddings_tsne[:, 1], c=clusters)
plt.colorbar()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-135-a9de63e180aa> in <cell line: 14>()
#      12 # Сокращение размерности с помощью t-SNE
#      13 tsne = TSNE(n_components=3, perplexity=3)
# ---> 14 embeddings_tsne = tsne.fit_transform(embeddings_np)
#      15
#      16
#
# /usr/local/lib/python3.10/dist-packages/sklearn/manifold/_t_sne.py in fit_transform(self, X, y)
#    1117         self._validate_params()
#    1118         self._check_params_vs_input(X)
# -> 1119         embedding = self._fit(X)
#    1120         self.embedding_ = embedding
#    1121         return self.embedding_
#
# /usr/local/lib/python3.10/dist-packages/sklearn/manifold/_t_sne.py in _fit(self, X, skip_num_points)
#    1010         degrees_of_freedom = max(self.n_components - 1, 1)
#    1011
# -> 1012         return self._tsne(
#    1013             P,
#    1014             degrees_of_freedom,
#
# /usr/local/lib/python3.10/dist-packages/sklearn/manifold/_t_sne.py in _tsne(self, P, degrees_of_freedom, n_samples, X_embedded, neighbors, skip_num_points)
#    1062         # higher learning rate controlled via the early exaggeration parameter
#    1063         P *= self.early_exaggeration
# -> 1064         params, kl_divergence, it = _gradient_descent(obj_func, params, **opt_args)
#    1065         if self.verbose:
#    1066             print(
#
# /usr/local/lib/python3.10/dist-packages/sklearn/manifold/_t_sne.py in _gradient_descent(objective, p0, it, n_iter, n_iter_check, n_iter_without_progress, momentum, learning_rate, min_gain, min_grad_norm, verbose, args, kwargs)
#     397         kwargs["compute_error"] = check_convergence or i == n_iter - 1
#     398
# --> 399         error, grad = objective(p, *args, **kwargs)
#     400
#     401         inc = update * grad < 0.0
#
# /usr/local/lib/python3.10/dist-packages/sklearn/manifold/_t_sne.py in _kl_divergence_bh(params, P, degrees_of_freedom, n_samples, n_components, angle, skip_num_points, verbose, compute_error, num_threads)
#     278
#     279     grad = np.zeros(X_embedded.shape, dtype=np.float32)
# --> 280     error = _barnes_hut_tsne.gradient(
#     281         val_P,
#     282         X_embedded,
#
# KeyboardInterrupt:

# %%
# Получение меток классов
labels = clusterer.labels_

# Создание словаря для сопоставления слов и меток классов
word_clusters = dict(zip(vocabulary, labels))

# %%
word_clusters

# %%
# Создание DataFrame из словаря
df = pd.DataFrame(list(word_clusters.items()), columns=['Слово', 'Метка'])

# Запись DataFrame в Excel
df.to_excel('/content/word_clusters.xlsx', index=False)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
import hdbscan

embeddings = embeddings.cpu()
# Преобразование тензора embeddings в массив numpy
embeddings_np = embeddings.detach().numpy()

# Сокращение размерности с помощью t-SNE
tsne = TSNE(n_components=2, perplexity=50, learning_rate=200)
embeddings_tsne = tsne.fit_transform(embeddings_np)

# Кластеризация с помощью HDBSCAN
clusterer = hdbscan.HDBSCAN(min_cluster_size=7)
clusters = clusterer.fit_predict(embeddings_tsne)

# Поиск индексов элементов, относящихся к кластеру -1
indices_to_keep = np.where(clusters != -1)[0]

# Фильтрация embeddings_tsne, оставляем только элементы, не относящиеся к кластеру -1
filtered_embeddings_tsne = embeddings_tsne[indices_to_keep]

# Визуализация результатов
plt.figure(figsize=(10, 10))
plt.scatter(filtered_embeddings_tsne[:, 0], filtered_embeddings_tsne[:, 1], c=clusters[indices_to_keep], cmap='rainbow', s=10, alpha=0.8)
plt.colorbar()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
import hdbscan

embeddings = embeddings.cpu()
# Преобразование тензора embeddings в массив numpy
embeddings_np = embeddings.detach().numpy()

# Сокращение размерности с помощью t-SNE
tsne = TSNE(n_components=2, perplexity=50, learning_rate=200)
embeddings_tsne = tsne.fit_transform(embeddings_np)

min_cluster_sizes = range(7, 22)  # Значения min_cluster_size

# Цикл для отображения карт с разными значениями min_cluster_size
for min_cluster_size in min_cluster_sizes:
    # Кластеризация с помощью HDBSCAN
    clusterer = hdbscan.HDBSCAN(min_cluster_size=min_cluster_size)
    clusters = clusterer.fit_predict(embeddings_tsne)

    # Поиск индексов элементов, относящихся к кластеру -1
    indices_to_keep = np.where(clusters != -1)[0]

    # Фильтрация embeddings_tsne, оставляем только элементы, не относящиеся к кластеру -1
    filtered_embeddings_tsne = embeddings_tsne[indices_to_keep]

    # Визуализация результатов
    plt.figure(figsize=(10, 10))
    plt.scatter(filtered_embeddings_tsne[:, 0], filtered_embeddings_tsne[:, 1], c=clusters[indices_to_keep], cmap='rainbow', s=10, alpha=0.8)
    plt.colorbar()
    plt.title(f'min_cluster_size={min_cluster_size}')  # Заголовок с текущим значением min_cluster_size
    plt.show()
